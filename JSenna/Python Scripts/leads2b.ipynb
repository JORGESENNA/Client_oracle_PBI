# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

#navegador.find_element(By.XPATH,'').send_keys("")

navegador = webdriver.Chrome()
navegador.get("https://app.leads2b.com/")
navegador.find_element(By.XPATH,'//*[@id="login-box-holder"]/div[2]/div/span/div[2]/form/div[1]/span/div/input').send_keys("lucas.pereira@papelex.com.br")
navegador.find_element(By.XPATH,'//*[@id="login-box-holder"]/div[2]/div/span/div[2]/form/div[2]/span/div/div/div/input').send_keys("Vrb24Barbe")
navegador.find_element(By.XPATH,'//*[@id="login:click:login.signin"]').send_keys(Keys.ENTER)
time.sleep(5)
navegador.get("https://app.leads2b.com/#/consulta-cnpj")
time.sleep(6)


navegador.find_element(By.XPATH,'//*[@id="app-wrapper__page-content"]/div/div/div/div[2]/div/input').send_keys("36.119.818/0001-75")
time.sleep(5)
navegador.find_element(By.XPATH,'//*[@id="company-data"]/div[17]/button').send_keys(Keys.ENTER)
time.sleep(5)
scores = navegador.find_element(By.CSS_SELECTOR, 'p')
print(scores.tag_name)
print(scores.get_attribute("class"))
print(scores.text)


for element3 in navegador.find_elements(By.CSS_SELECTOR, 'span'):
    print(element3.text)
    print(element3.tag_name)
    print(element3.get_attribute("class"))

for element2 in navegador.find_elements(By.CSS_SELECTOR, 'label'):
    print(element2.text)
    print(element2.tag_name)
    print(element2.get_attribute("class"))

for element in navegador.find_elements(By.CSS_SELECTOR, 'p'):
    print(element.text)    
    print(element.tag_name)
    print(element.get_attribute("class"))
    
    
    
navegador.quit()
# Out:
# p
# font-color-tertiary
# Quer entender mais do Consulta CNPJ? Veja aqui o vídeo que explica tudo! Ou acesse o artigo da nossa Central de Ajuda.
#
# span
#
#
# span
# sidebar-menu__span
#
# span
# sidebar-menu__span
#
# span
# sidebar-menu__span
#
# span
# accordion-button__content w-100
#
# span
# sidebar-submenu__span
#
# span
# sidebar-submenu-item__label
#
# span
# sidebar-submenu-item__label
#
# span
# sidebar-submenu-item__label
#
# span
# sidebar-submenu-item__label
#
# span
# sidebar-submenu-item__label
#
# span
# sidebar-submenu-item__label
#
# span
# sidebar-submenu-item__label
#
# span
# sidebar-submenu-item__label
#
# span
# pt-2 pb-2 fs-2 fw-bold d-flex sidebar-submenu-item__subtitle
#
# span
# sidebar-submenu-item__label
#
# span
# pt-2 pb-2 sidebar-submenu-item__locked
#
# span
# sidebar-submenu-item__label
#
# span
# pt-2 pb-2 sidebar-submenu-item__locked
#
# span
# sidebar-submenu-item__label
#
# span
# accordion-button__content w-100
#
# span
# ...
